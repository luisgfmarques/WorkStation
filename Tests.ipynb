# %%
p = []
k=0
for n in range(100):
    p.append(k)
    k = k+0.1

# %%
list(p)
# Out:
# [0.01,
#  0.11,
#  0.21000000000000002,
#  0.31000000000000005,
#  0.41000000000000003,
#  0.51,
#  0.61,
#  0.71,
#  0.8099999999999999,
#  0.9099999999999999,
#  1.0099999999999998,
#  1.1099999999999999,
#  1.21,
#  1.31,
#  1.4100000000000001,
#  1.5100000000000002,
#  1.6100000000000003,
#  1.7100000000000004,
#  1.8100000000000005,
#  1.9100000000000006,
#  2.0100000000000002,
#  2.1100000000000003,
#  2.2100000000000004,
#  2.3100000000000005,
#  2.4100000000000006,
#  2.5100000000000007,
#  2.6100000000000008,
#  2.710000000000001,
#  2.810000000000001,
#  2.910000000000001,
#  3.010000000000001,
#  3.110000000000001,
#  3.2100000000000013,
#  3.3100000000000014,
#  3.4100000000000015,
#  3.5100000000000016,
#  3.6100000000000017,
#  3.7100000000000017,
#  3.810000000000002,
#  3.910000000000002,
#  4.010000000000002,
#  4.110000000000001,
#  4.210000000000001,
#  4.3100000000000005,
#  4.41,
#  4.51,
#  4.609999999999999,
#  4.709999999999999,
#  4.809999999999999,
# ...
